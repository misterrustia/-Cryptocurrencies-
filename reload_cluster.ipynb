# %%
file = "clustered_df.csv"
df_clust= pd.read_csv(file)
df_crypto.head()
# Out:
#   Unnamed: 0      PC_1      PC_2      PC_3  class   CoinName Algorithm  \
# 0         42 -0.319730  0.936061 -0.520636      0    42 Coin    Scrypt
# 1        404 -0.303100  0.935908 -0.520905      0    404Coin    Scrypt
# 2       1337  2.307831  1.731695 -0.645229      0  EliteCoin       X13
# 3        BTC -0.129939 -1.277896  0.193954      2    Bitcoin   SHA-256
# 4        ETH -0.160417 -1.946267  0.286727      2   Ethereum    Ethash
#
#   ProofType  TotalCoinsMined  TotalCoinSupply
# 0   PoW/PoS     4.199995e+01     4.200000e+01
# 1   PoW/PoS     1.055185e+09     5.320000e+08
# 2   PoW/PoS     2.927942e+10     3.141593e+11
# 3       PoW     1.792718e+07     2.100000e+07
# 4       PoW     1.076842e+08     0.000000e+00

# %%
df_crypto = df_crypto.set_index(["Unnamed: 0"])
df_crypto.head()
# Out:
#                 PC_1      PC_2      PC_3  class   CoinName Algorithm  \
# Unnamed: 0
# 42         -0.319730  0.936061 -0.520636      0    42 Coin    Scrypt
# 404        -0.303100  0.935908 -0.520905      0    404Coin    Scrypt
# 1337        2.307831  1.731695 -0.645229      0  EliteCoin       X13
# BTC        -0.129939 -1.277896  0.193954      2    Bitcoin   SHA-256
# ETH        -0.160417 -1.946267  0.286727      2   Ethereum    Ethash
#
#            ProofType  TotalCoinsMined  TotalCoinSupply
# Unnamed: 0
# 42           PoW/PoS     4.199995e+01     4.200000e+01
# 404          PoW/PoS     1.055185e+09     5.320000e+08
# 1337         PoW/PoS     2.927942e+10     3.141593e+11
# BTC              PoW     1.792718e+07     2.100000e+07
# ETH              PoW     1.076842e+08     0.000000e+00

# %%
import pandas as pd

# %%
df_crypto.index.name = None
df_crypto.head()
# Out:
#           PC_1      PC_2      PC_3  class   CoinName Algorithm ProofType  \
# 42   -0.319730  0.936061 -0.520636      0    42 Coin    Scrypt   PoW/PoS
# 404  -0.303100  0.935908 -0.520905      0    404Coin    Scrypt   PoW/PoS
# 1337  2.307831  1.731695 -0.645229      0  EliteCoin       X13   PoW/PoS
# BTC  -0.129939 -1.277896  0.193954      2    Bitcoin   SHA-256       PoW
# ETH  -0.160417 -1.946267  0.286727      2   Ethereum    Ethash       PoW
#
#       TotalCoinsMined  TotalCoinSupply
# 42       4.199995e+01     4.200000e+01
# 404      1.055185e+09     5.320000e+08
# 1337     2.927942e+10     3.141593e+11
# BTC      1.792718e+07     2.100000e+07
# ETH      1.076842e+08     0.000000e+00
